# %%
import pandas as pd
pd.set_option('display.max_column', 250)
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-notebook')
from matplotlib import rcParams
rcParams['figure.figsize'] = (5, 3)
rcParams['figure.dpi'] = 150
# %matplotlib inline

# %%
df = pd.read_csv('Outputs/covtype/covtype_PL.csv')

# %%
df.head()
# Out:
#    learning evaluation instances  evaluation time (cpu seconds)  \
# 0                          100.0                       0.023880
# 1                          200.0                       0.052982
# 2                          300.0                       0.068433
# 3                          400.0                       0.082274
# 4                          500.0                       0.096707
#
#    model cost (RAM-Hours)  classified instances  \
# 0            5.617820e-10                 100.0
# 1            1.246413e-09                 200.0
# 2            1.610092e-09                 300.0
# 3            1.960941e-09                 400.0
# 4            2.300541e-09                 500.0
#
#    classifications correct (percent)  Kappa Statistic (percent)  \
# 0                               75.0                  58.277704
# 1                               74.0                  57.391019
# 2                               77.0                  60.020087
# 3                               76.5                  58.901714
# 4                               77.8                  61.564032
#
#    Kappa Temporal Statistic (percent)  Kappa M Statistic (percent)  \
# 0                           30.555556                    47.916667
# 1                           36.585366                    42.222222
# 2                           46.511628                    44.800000
# 3                           43.030303                    44.705882
# 4                           46.889952                    48.372093
#
#   F1 Score (percent) F1 Score for class 0 (percent)  \
# 0                  ?              38.46153846153846
# 1                  ?              52.74725274725274
# 2                  ?               62.0253164556962
# 3                  ?              63.96396396396396
# 4                  ?              65.71428571428572
#
#   F1 Score for class 1 (percent) F1 Score for class 2 (percent)  \
# 0               73.6842105263158                              ?
# 1              77.72511848341232                              ?
# 2              81.39534883720931                              ?
# 3              80.61002178649237                              ?
# 4               81.2720848056537                              ?
#
#   F1 Score for class 3 (percent) F1 Score for class 4 (percent)  \
# 0                              ?              85.71428571428572
# 1                              ?              85.71428571428572
# 2                              ?              85.71428571428572
# 3                              ?              84.03361344537815
# 4                              ?              87.01298701298703
#
#   F1 Score for class 5 (percent) F1 Score for class 6 (percent)  \
# 0                              ?                              ?
# 1                              ?                              ?
# 2                              ?                              ?
# 3                              ?                              ?
# 4                              ?                              ?
#
#   Precision (percent) Precision for class 0 (percent)  \
# 0                   ?               33.33333333333333
# 1                   ?                            50.0
# 2                   ?               61.25000000000001
# 3                   ?               63.39285714285714
# 4                   ?                64.7887323943662
#
#   Precision for class 1 (percent) Precision for class 2 (percent)  \
# 0               75.67567567567568                               ?
# 1               78.84615384615384                               ?
# 2                81.3953488372093                               ?
# 3               79.74137931034483                               ?
# 4               80.98591549295774                               ?
#
#   Precision for class 3 (percent) Precision for class 4 (percent)  \
# 0                               ?                            87.5
# 1                               ?                            87.5
# 2                               ?                            87.5
# 3                               ?               89.28571428571429
# 4                               ?               90.54054054054053
#
#   Precision for class 5 (percent) Precision for class 6 (percent)  \
# 0                               ?                               ?
# 1                               ?                               ?
# 2                               ?                               ?
# 3                               ?                               ?
# 4                               ?                               ?
#
#   Recall (percent) Recall for class 0 (percent) Recall for class 1 (percent)  \
# 0                ?            45.45454545454545             71.7948717948718
# 1                ?            55.81395348837209            76.63551401869158
# 2                ?            62.82051282051282             81.3953488372093
# 3                ?            64.54545454545455             81.4977973568282
# 4                ?            66.66666666666666            81.56028368794325
#
#   Recall for class 2 (percent) Recall for class 3 (percent)  \
# 0                            ?                            ?
# 1                            ?                            ?
# 2                            ?                            ?
# 3                            ?                            ?
# 4                            ?                            ?
#
#   Recall for class 4 (percent) Recall for class 5 (percent)  \
# 0                         84.0                            ?
# 1                         84.0                            ?
# 2                         84.0                            ?
# 3            79.36507936507937                            ?
# 4                        83.75                            ?
#
#   Recall for class 6 (percent)  model training instances  \
# 0                            ?                      21.0
# 1                            ?                      35.0
# 2                            ?                      89.0
# 3                            ?                      41.0
# 4                            ?                      58.0
#
#    model serialized size (bytes)  Change detected
# 0                        10968.0              3.0
# 1                        10976.0              2.0
# 2                        11008.0              1.0
# 3                        14504.0              2.0
# 4                        10984.0              2.0

# %%
df.info()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/env_CD/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-28-05b2c6487875> in <module>
# ----> 1 df[['F1 Score (percent)'] != '?']
#
# ~/anaconda3/envs/env_CD/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/envs/env_CD/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: True

# %%
print(df['classifications correct (percent)'].mean())
print(df['classifications correct (percent)'].mean())
print(df['Change detected'].sum())
# Out:
# 89.01774193988959
# 89.01774193988959
# 5205.0
