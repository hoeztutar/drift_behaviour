# %%
import pandas as pd
pd.set_option('display.max_column', 250)
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-notebook')
from matplotlib import rcParams
rcParams['figure.figsize'] = (6, 4)
rcParams['figure.dpi'] = 150

# %%
import arff
data = arff.load(open('../data/SINE.arff'))
cnames = [i[0] for i in data['attributes']]
df = pd.DataFrame(data['data'], columns=cnames)
df.head()
# Out:
#        att1      att2      att3      att4     class
# 0  0.730878  0.410081  0.207715  0.332717  positive
# 1  0.967756  0.006117  0.963705  0.939865  positive
# 2  0.947195  0.937082  0.397174  0.347518  negative
# 3  0.294057  0.506484  0.115967  0.770536  negative
# 4  0.659893  0.156747  0.378202  0.139763  positive

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 5 columns):
# att1     50000 non-null float64
# att2     50000 non-null float64
# att3     50000 non-null float64
# att4     50000 non-null float64
# class    50000 non-null object
# dtypes: float64(4), object(1)
# memory usage: 1.9+ MB

# %%
df.describe()
# Out:
#                att1          att2          att3          att4
# count  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.500035      0.513418      0.500070      0.498887
# std        0.285415      0.290101      0.288530      0.289483
# min        0.000009      0.000015      0.000009      0.000015
# 25%        0.256593      0.264861      0.249364      0.247565
# 50%        0.499977      0.518814      0.502916      0.499887
# 75%        0.741101      0.769668      0.748455      0.749069
# max        0.999987      0.999997      0.999934      0.999988

# %%
df.groupby('class')['class'].count()
# Out:
# class
# negative    26024
# positive    23976
# Name: class, dtype: int64

# %%
f, axes = plt.subplots(2, 2)

for i in range(2):
    sns.distplot(df[df['class']=='positive'].loc[:25000,'att'+str(i+1)], ax=axes[0,i], bins=15, label='Positive')
    sns.distplot(df[df['class']=='negative'].loc[:25000,'att'+str(i+1)], ax=axes[0,i], bins=15, label='Negative')
    sns.distplot(df[df['class']=='positive'].loc[25000:,'att'+str(i+1)], ax=axes[1,i], bins=15, label='Positive')
    sns.distplot(df[df['class']=='negative'].loc[25000:,'att'+str(i+1)], ax=axes[1,i], bins=15, label='Negative')

plt.legend()

# %%
df[df['class']=='negative'].iloc[25000:,i].count()
# Out:
# 1024

# %%
df[df['class']=='positive'].iloc[25000:,:]
# Out:
# Empty DataFrame
# Columns: [att1, att2, att3, att4, class]
# Index: []
